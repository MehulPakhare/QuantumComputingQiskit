# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '2.2.1'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
import os

# Read sensitive info from environment variables
api_key = os.environ.get("QISKIT_IBM_TOKEN")
instance = os.environ.get("QISKIT_IBM_INSTANCE")

service = QiskitRuntimeService(
    token=api_key,
    instance=instance
)
# Out:
# management.get:WARNING:2025-09-30 10:41:21,844: Loading default saved account

# %%
# QiskitRuntimeService.save_account( token="UhHn0rgVWvqvwwjtHzJ__ZS7o0jTJTn2I0lXMREbHGdQ",
#  instance="crn:v1:bluemix:public:quantum-computing:us-east:a/8c4d15a56d1342d9818d743c3da92211:1a53b5a6-1d53-49aa-b862-7e3f86a869eb::")

from qiskit_ibm_runtime import QiskitRuntimeService
import os

api_key = os.environ.get("QISKIT_IBM_TOKEN")
instance = os.environ.get("QISKIT_IBM_INSTANCE")

QiskitRuntimeService.save_account(
    token=api_key,
    instance=instance
)
# Out:
# ---------------------------------------------------------------------------
# InvalidAccountError                       Traceback (most recent call last)
# Cell In[13], line 10
#       7 api_key = os.environ.get("QISKIT_IBM_TOKEN")
#       8 instance = os.environ.get("QISKIT_IBM_INSTANCE")
# ---> 10 QiskitRuntimeService.save_account(
#      11     token=api_key,
#      12     instance=instance
#      13 )
#
# File ~/miniconda/envs/cwq/lib/python3.13/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:822, in QiskitRuntimeService.save_account(token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#     771 @staticmethod
#     772 def save_account(
#     773     token: Optional[str] = None,
#    (...)    786     tags: Optional[List[str]] = None,
#     787 ) -> None:
#     788     """Save the account to disk for future use.
#     789
#     790     Args:
#    (...)    819
#     820     """
# --> 822     AccountManager.save(
#     823         token=token,
#     824         url=url,
#     825         instance=instance,
#     826         channel=channel,
#     827         filename=filename,
#     828         name=name,
#     829         proxies=ProxyConfiguration(**proxies) if proxies else None,
#     830         verify=verify,
#     831         overwrite=overwrite,
#     832         set_as_default=set_as_default,
#     833         private_endpoint=private_endpoint,
#     834         region=region,
#     835         plans_preference=plans_preference,
#     836         tags=tags,
#     837     )
#
# File ~/miniconda/envs/cwq/lib/python3.13/site-packages/qiskit_ibm_runtime/accounts/management.py:82, in AccountManager.save(cls, token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#      62 filename = os.path.expanduser(filename)
#      64 config = Account.create_account(
#      65     channel=channel,
#      66     token=token,
#    (...)     74     tags=tags,
#      75 )
#      76 return save_config(
#      77     filename=filename,
#      78     name=name,
#      79     overwrite=overwrite,
#      80     config=config
#      81     # avoid storing invalid accounts
# ---> 82     .validate().to_saved_format(),
#      83     set_as_default=set_as_default,
#      84 )
#
# File ~/miniconda/envs/cwq/lib/python3.13/site-packages/qiskit_ibm_runtime/accounts/account.py:187, in Account.validate(self)
#     185 self._assert_valid_preferences(self.region, self.plans_preference, self.tags)
#     186 self._assert_valid_channel(self.channel)
# --> 187 self._assert_valid_token(self.token)
#     188 self._assert_valid_url(self.url)
#     189 self._assert_valid_instance(self.instance)
#
# File ~/miniconda/envs/cwq/lib/python3.13/site-packages/qiskit_ibm_runtime/accounts/account.py:206, in Account._assert_valid_token(token)
#     204 """Assert that the token is valid."""
#     205 if not (isinstance(token, str) and len(token) > 0):
# --> 206     raise InvalidAccountError(
#     207         f"Invalid `token` value. Expected a non-empty string, got '{token}'."
#     208     )
#
# InvalidAccountError: "Invalid `token` value. Expected a non-empty string, got 'None'."

# %%
backend = service.backend(name = "ibm_brisbane")

# %%
backend.num_qubits
# Out:
# 127

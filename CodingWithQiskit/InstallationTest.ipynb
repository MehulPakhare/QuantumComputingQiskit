# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '2.2.1'

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
 
# Saved accounts are not used when a token is passed in. The service is initialized with credentials that are not saved.
service = QiskitRuntimeService(
  # Delete your key on the API keys page after entering this code:
  token="UhHn0rgVWvqvwwjtHzJ__ZS7o0jTJTn2I0lXMREbHGdQ",
  instance="crn:v1:bluemix:public:quantum-computing:us-east:a/8c4d15a56d1342d9818d743c3da92211:1a53b5a6-1d53-49aa-b862-7e3f86a869eb::"
  )
# Out:
# qiskit_runtime_service._discover_account:WARNING:2025-09-30 07:58:37,280: Loading account with the given token. A saved account will not be used.

# %%
QiskitRuntimeService.save_account( token="UhHn0rgVWvqvwwjtHzJ__ZS7o0jTJTn2I0lXMREbHGdQ",
  instance="crn:v1:bluemix:public:quantum-computing:us-east:a/8c4d15a56d1342d9818d743c3da92211:1a53b5a6-1d53-49aa-b862-7e3f86a869eb::")
# Out:
# ---------------------------------------------------------------------------
# AccountAlreadyExistsError                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 QiskitRuntimeService.save_account( token="UhHn0rgVWvqvwwjtHzJ__ZS7o0jTJTn2I0lXMREbHGdQ",
#       2   instance="crn:v1:bluemix:public:quantum-computing:us-east:a/8c4d15a56d1342d9818d743c3da92211:1a53b5a6-1d53-49aa-b862-7e3f86a869eb::")
#
# File ~/miniconda/envs/cwq/lib/python3.13/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:822, in QiskitRuntimeService.save_account(token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#     771 @staticmethod
#     772 def save_account(
#     773     token: Optional[str] = None,
#    (...)    786     tags: Optional[List[str]] = None,
#     787 ) -> None:
#     788     """Save the account to disk for future use.
#     789
#     790     Args:
#    (...)    819
# ...

# %%
backend = service.backend(name = "ibm_brisbane")

# %%
backend.num_qubits
# Out:
# 127
